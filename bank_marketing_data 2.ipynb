# %%
import pandas as pd

bank_marketing_data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/bank_marketing_data/training_set_label.csv" )

# %%
bank_marketing_data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  subscribe
# 0  unknown    5   may       261         1     -1         0  unknown          0
# 1  unknown    5   may       151         1     -1         0  unknown          0
# 2  unknown    5   may        76         1     -1         0  unknown          0
# 3  unknown    5   may        92         1     -1         0  unknown          0
# 4  unknown    5   may       198         1     -1         0  unknown          0

# %%
bank_marketing_data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0        unknown    5   may       261         1     -1         0  unknown
# 1        unknown    5   may       151         1     -1         0  unknown
# 2        unknown    5   may        76         1     -1         0  unknown
# 3        unknown    5   may        92         1     -1         0  unknown
# 4        unknown    5   may       198         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45207   cellular   17   nov       456         2     -1         0  unknown
# 45208   cellular   17   nov      1127         5    184         3  success
# 45209  telephone   17   nov       508         4     -1         0  unknown
# 45210   cellular   17   nov       361         2    188        11    other
#
#        subscribe
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 45206          1
# 45207          1
# 45208          1
# 45209          0
# 45210          0
#
# [45211 rows x 17 columns]

# %%
import numpy as np
# Remove rows with missing target, separate target from predictors
X=bank_marketing_data

y = X['subscribe']             
X.drop(['subscribe'], axis=1, inplace=True)
from sklearn.model_selection import train_test_split
# Break off validation set from training data
X_train,X_valid,y_train,y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                                random_state=0)
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# %%
conda install -c anaconda py-xgboost
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ENKOYAOUNDE\anaconda3
#
#   added / updated specs:
#     - py-xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0          12 KB  anaconda
#     conda-4.9.0                |           py37_0         3.1 MB  anaconda
#     libxgboost-0.90            |                1         3.9 MB  anaconda
#     py-xgboost-0.90            |           py37_1          80 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         7.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  anaconda/win-64::_py-xgboost-mutex-2.0-cpu_0
#   libxgboost         anaconda/win-64::libxgboost-0.90-1
#   py-xgboost         anaconda/win-64::py-xgboost-0.90-py37_1
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.2-py37_0 --> anaconda::conda-4.9.0-py37_0
#
#
#
# Downloading and Extracting Packages
#
# libxgboost-0.90      | 3.9 MB    |            |   0%
# libxgboost-0.90      | 3.9 MB    |            |   0%
# libxgboost-0.90      | 3.9 MB    |            |   1%
# libxgboost-0.90      | 3.9 MB    | 1          |   1%
# libxgboost-0.90      | 3.9 MB    | 1          |   2%
# libxgboost-0.90      | 3.9 MB    | 2          |   2%
# libxgboost-0.90      | 3.9 MB    | 2          |   2%
# libxgboost-0.90      | 3.9 MB    | 2          |   3%
# libxgboost-0.90      | 3.9 MB    | 3          |   3%
# libxgboost-0.90      | 3.9 MB    | 3          |   4%
# libxgboost-0.90      | 3.9 MB    | 4          |   4%
# libxgboost-0.90      | 3.9 MB    | 4          |   4%
# libxgboost-0.90      | 3.9 MB    | 4          |   5%
# libxgboost-0.90      | 3.9 MB    | 5          |   5%
# libxgboost-0.90      | 3.9 MB    | 5          |   6%
# libxgboost-0.90      | 3.9 MB    | 6          |   6%
# libxgboost-0.90      | 3.9 MB    | 6          |   6%
# libxgboost-0.90      | 3.9 MB    | 6          |   7%
# libxgboost-0.90      | 3.9 MB    | 7          |   7%
# libxgboost-0.90      | 3.9 MB    | 7          |   8%
# libxgboost-0.90      | 3.9 MB    | 8          |   8%
# libxgboost-0.90      | 3.9 MB    | 8          |   9%
# libxgboost-0.90      | 3.9 MB    | 8          |   9%
# libxgboost-0.90      | 3.9 MB    | 9          |   9%
# libxgboost-0.90      | 3.9 MB    | 9          |  10%
# libxgboost-0.90      | 3.9 MB    | #          |  10%
# libxgboost-0.90      | 3.9 MB    | #          |  11%
# libxgboost-0.90      | 3.9 MB    | #          |  11%
# libxgboost-0.90      | 3.9 MB    | #1         |  11%
# libxgboost-0.90      | 3.9 MB    | #1         |  12%
# libxgboost-0.90      | 3.9 MB    | #2         |  12%
# libxgboost-0.90      | 3.9 MB    | #2         |  13%
# libxgboost-0.90      | 3.9 MB    | #2         |  13%
# libxgboost-0.90      | 3.9 MB    | #3         |  13%
# libxgboost-0.90      | 3.9 MB    | #3         |  14%
# libxgboost-0.90      | 3.9 MB    | #4         |  14%
# libxgboost-0.90      | 3.9 MB    | #4         |  15%
# libxgboost-0.90      | 3.9 MB    | #5         |  15%
# libxgboost-0.90      | 3.9 MB    | #5         |  15%
# libxgboost-0.90      | 3.9 MB    | #5         |  16%
# libxgboost-0.90      | 3.9 MB    | #6         |  16%
# libxgboost-0.90      | 3.9 MB    | #6         |  17%
# libxgboost-0.90      | 3.9 MB    | #7         |  17%
# libxgboost-0.90      | 3.9 MB    | #7         |  17%
# libxgboost-0.90      | 3.9 MB    | #7         |  18%
# libxgboost-0.90      | 3.9 MB    | #8         |  18%
# libxgboost-0.90      | 3.9 MB    | #8         |  19%
# libxgboost-0.90      | 3.9 MB    | #9         |  19%
# libxgboost-0.90      | 3.9 MB    | #9         |  19%
# libxgboost-0.90      | 3.9 MB    | #9         |  20%
# libxgboost-0.90      | 3.9 MB    | ##         |  20%
# libxgboost-0.90      | 3.9 MB    | ##1        |  21%
# libxgboost-0.90      | 3.9 MB    | ##1        |  21%
# libxgboost-0.90      | 3.9 MB    | ##1        |  22%
# libxgboost-0.90      | 3.9 MB    | ##2        |  22%
# libxgboost-0.90      | 3.9 MB    | ##2        |  23%
# libxgboost-0.90      | 3.9 MB    | ##3        |  23%
# libxgboost-0.90      | 3.9 MB    | ##3        |  24%
# libxgboost-0.90      | 3.9 MB    | ##4        |  24%
# libxgboost-0.90      | 3.9 MB    | ##4        |  25%
# libxgboost-0.90      | 3.9 MB    | ##5        |  25%
# libxgboost-0.90      | 3.9 MB    | ##5        |  26%
# libxgboost-0.90      | 3.9 MB    | ##5        |  26%
# libxgboost-0.90      | 3.9 MB    | ##6        |  26%
# libxgboost-0.90      | 3.9 MB    | ##6        |  27%
# libxgboost-0.90      | 3.9 MB    | ##7        |  27%
# libxgboost-0.90      | 3.9 MB    | ##7        |  28%
# libxgboost-0.90      | 3.9 MB    | ##7        |  28%
# libxgboost-0.90      | 3.9 MB    | ##8        |  28%
# libxgboost-0.90      | 3.9 MB    | ##8        |  29%
# libxgboost-0.90      | 3.9 MB    | ##9        |  29%
# libxgboost-0.90      | 3.9 MB    | ###        |  30%
# libxgboost-0.90      | 3.9 MB    | ###        |  30%
# libxgboost-0.90      | 3.9 MB    | ###        |  31%
# libxgboost-0.90      | 3.9 MB    | ###1       |  31%
# libxgboost-0.90      | 3.9 MB    | ###1       |  32%
# libxgboost-0.90      | 3.9 MB    | ###2       |  32%
# libxgboost-0.90      | 3.9 MB    | ###2       |  33%
# libxgboost-0.90      | 3.9 MB    | ###3       |  34%
# libxgboost-0.90      | 3.9 MB    | ###4       |  34%
# libxgboost-0.90      | 3.9 MB    | ###4       |  34%
# libxgboost-0.90      | 3.9 MB    | ###4       |  35%
# libxgboost-0.90      | 3.9 MB    | ###5       |  35%
# libxgboost-0.90      | 3.9 MB    | ###5       |  36%
# libxgboost-0.90      | 3.9 MB    | ###6       |  36%
# libxgboost-0.90      | 3.9 MB    | ###7       |  37%
# libxgboost-0.90      | 3.9 MB    | ###7       |  38%
# libxgboost-0.90      | 3.9 MB    | ###8       |  38%
# libxgboost-0.90      | 3.9 MB    | ###8       |  39%
# libxgboost-0.90      | 3.9 MB    | ###9       |  39%
# libxgboost-0.90      | 3.9 MB    | ####       |  40%
# libxgboost-0.90      | 3.9 MB    | ####       |  41%
# libxgboost-0.90      | 3.9 MB    | ####1      |  41%
# libxgboost-0.90      | 3.9 MB    | ####1      |  42%
# libxgboost-0.90      | 3.9 MB    | ####2      |  42%
# libxgboost-0.90      | 3.9 MB    | ####2      |  43%
# libxgboost-0.90      | 3.9 MB    | ####2      |  43%
# libxgboost-0.90      | 3.9 MB    | ####3      |  43%
# libxgboost-0.90      | 3.9 MB    | ####4      |  44%
# libxgboost-0.90      | 3.9 MB    | ####5      |  45%
# libxgboost-0.90      | 3.9 MB    | ####5      |  45%
# libxgboost-0.90      | 3.9 MB    | ####5      |  46%
# libxgboost-0.90      | 3.9 MB    | ####6      |  46%
# libxgboost-0.90      | 3.9 MB    | ####7      |  47%
# libxgboost-0.90      | 3.9 MB    | ####7      |  47%
# libxgboost-0.90      | 3.9 MB    | ####7      |  48%
# libxgboost-0.90      | 3.9 MB    | ####8      |  48%
# libxgboost-0.90      | 3.9 MB    | ####8      |  49%
# libxgboost-0.90      | 3.9 MB    | ####9      |  49%
# libxgboost-0.90      | 3.9 MB    | ####9      |  49%
# libxgboost-0.90      | 3.9 MB    | #####      |  50%
# libxgboost-0.90      | 3.9 MB    | #####      |  51%
# libxgboost-0.90      | 3.9 MB    | #####1     |  51%
# libxgboost-0.90      | 3.9 MB    | #####1     |  51%
# libxgboost-0.90      | 3.9 MB    | #####1     |  52%
# libxgboost-0.90      | 3.9 MB    | #####2     |  52%
# libxgboost-0.90      | 3.9 MB    | #####2     |  53%
# libxgboost-0.90      | 3.9 MB    | #####3     |  54%
# libxgboost-0.90      | 3.9 MB    | #####3     |  54%
# libxgboost-0.90      | 3.9 MB    | #####4     |  54%
# libxgboost-0.90      | 3.9 MB    | #####4     |  55%
# libxgboost-0.90      | 3.9 MB    | #####5     |  55%
# libxgboost-0.90      | 3.9 MB    | #####5     |  56%
# libxgboost-0.90      | 3.9 MB    | #####5     |  56%
# libxgboost-0.90      | 3.9 MB    | #####6     |  56%
# libxgboost-0.90      | 3.9 MB    | #####7     |  57%
# libxgboost-0.90      | 3.9 MB    | #####7     |  58%
# libxgboost-0.90      | 3.9 MB    | #####7     |  58%
# libxgboost-0.90      | 3.9 MB    | #####8     |  58%
# libxgboost-0.90      | 3.9 MB    | #####9     |  59%
# libxgboost-0.90      | 3.9 MB    | #####9     |  60%
# libxgboost-0.90      | 3.9 MB    | ######     |  60%
# libxgboost-0.90      | 3.9 MB    | ######     |  60%
# libxgboost-0.90      | 3.9 MB    | ######1    |  61%
# libxgboost-0.90      | 3.9 MB    | ######1    |  62%
# libxgboost-0.90      | 3.9 MB    | ######2    |  62%
# libxgboost-0.90      | 3.9 MB    | ######2    |  62%
# libxgboost-0.90      | 3.9 MB    | ######2    |  63%
# libxgboost-0.90      | 3.9 MB    | ######3    |  63%
# libxgboost-0.90      | 3.9 MB    | ######3    |  64%
# libxgboost-0.90      | 3.9 MB    | ######4    |  64%
# libxgboost-0.90      | 3.9 MB    | ######4    |  65%
# libxgboost-0.90      | 3.9 MB    | ######5    |  66%
# libxgboost-0.90      | 3.9 MB    | ######6    |  66%
# libxgboost-0.90      | 3.9 MB    | ######6    |  66%
# libxgboost-0.90      | 3.9 MB    | ######6    |  67%
# libxgboost-0.90      | 3.9 MB    | ######7    |  67%
# libxgboost-0.90      | 3.9 MB    | ######7    |  68%
# libxgboost-0.90      | 3.9 MB    | ######8    |  68%
# libxgboost-0.90      | 3.9 MB    | ######8    |  69%
# libxgboost-0.90      | 3.9 MB    | ######9    |  69%
# libxgboost-0.90      | 3.9 MB    | ######9    |  70%
# libxgboost-0.90      | 3.9 MB    | #######    |  70%
# libxgboost-0.90      | 3.9 MB    | #######    |  71%
# libxgboost-0.90      | 3.9 MB    | #######1   |  71%
# libxgboost-0.90      | 3.9 MB    | #######2   |  72%
# libxgboost-0.90      | 3.9 MB    | #######2   |  73%
# libxgboost-0.90      | 3.9 MB    | #######2   |  73%
# libxgboost-0.90      | 3.9 MB    | #######3   |  74%
# libxgboost-0.90      | 3.9 MB    | #######4   |  74%
# libxgboost-0.90      | 3.9 MB    | #######4   |  75%
# libxgboost-0.90      | 3.9 MB    | #######5   |  75%
# libxgboost-0.90      | 3.9 MB    | #######5   |  75%
# libxgboost-0.90      | 3.9 MB    | #######5   |  76%
# libxgboost-0.90      | 3.9 MB    | #######6   |  76%
# libxgboost-0.90      | 3.9 MB    | #######6   |  77%
# libxgboost-0.90      | 3.9 MB    | #######7   |  77%
# libxgboost-0.90      | 3.9 MB    | #######7   |  77%
# libxgboost-0.90      | 3.9 MB    | #######8   |  78%
# libxgboost-0.90      | 3.9 MB    | #######9   |  79%
# libxgboost-0.90      | 3.9 MB    | #######9   |  79%
# libxgboost-0.90      | 3.9 MB    | #######9   |  80%
# libxgboost-0.90      | 3.9 MB    | ########   |  81%
# libxgboost-0.90      | 3.9 MB    | ########1  |  81%
# libxgboost-0.90      | 3.9 MB    | ########1  |  81%
# libxgboost-0.90      | 3.9 MB    | ########2  |  82%
# libxgboost-0.90      | 3.9 MB    | ########2  |  83%
# libxgboost-0.90      | 3.9 MB    | ########3  |  84%
# libxgboost-0.90      | 3.9 MB    | ########3  |  84%
# libxgboost-0.90      | 3.9 MB    | ########4  |  84%
# libxgboost-0.90      | 3.9 MB    | ########4  |  85%
# libxgboost-0.90      | 3.9 MB    | ########5  |  85%
# libxgboost-0.90      | 3.9 MB    | ########5  |  86%
# libxgboost-0.90      | 3.9 MB    | ########5  |  86%
# libxgboost-0.90      | 3.9 MB    | ########6  |  87%
# libxgboost-0.90      | 3.9 MB    | ########7  |  88%
# libxgboost-0.90      | 3.9 MB    | ########7  |  88%
# libxgboost-0.90      | 3.9 MB    | ########8  |  88%
# libxgboost-0.90      | 3.9 MB    | ########8  |  89%
# libxgboost-0.90      | 3.9 MB    | ########9  |  89%
# libxgboost-0.90      | 3.9 MB    | ########9  |  90%
# libxgboost-0.90      | 3.9 MB    | #########  |  90%
# libxgboost-0.90      | 3.9 MB    | #########  |  90%
# libxgboost-0.90      | 3.9 MB    | #########  |  91%
# libxgboost-0.90      | 3.9 MB    | #########1 |  91%
# libxgboost-0.90      | 3.9 MB    | #########1 |  92%
# libxgboost-0.90      | 3.9 MB    | #########2 |  92%
# libxgboost-0.90      | 3.9 MB    | #########2 |  92%
# libxgboost-0.90      | 3.9 MB    | #########3 |  93%
# libxgboost-0.90      | 3.9 MB    | #########3 |  94%
# libxgboost-0.90      | 3.9 MB    | #########4 |  94%
# libxgboost-0.90      | 3.9 MB    | #########4 |  94%
# libxgboost-0.90      | 3.9 MB    | #########4 |  95%
# libxgboost-0.90      | 3.9 MB    | #########5 |  95%
# libxgboost-0.90      | 3.9 MB    | #########5 |  96%
# libxgboost-0.90      | 3.9 MB    | #########6 |  97%
# libxgboost-0.90      | 3.9 MB    | #########7 |  97%
# libxgboost-0.90      | 3.9 MB    | #########8 |  98%
# libxgboost-0.90      | 3.9 MB    | #########8 |  99%
# libxgboost-0.90      | 3.9 MB    | #########8 |  99%
# libxgboost-0.90      | 3.9 MB    | #########9 |  99%
# libxgboost-0.90      | 3.9 MB    | ########## | 100%
#
# _py-xgboost-mutex-2. | 12 KB     |            |   0%
# _py-xgboost-mutex-2. | 12 KB     | ########## | 100%
#
# py-xgboost-0.90      | 80 KB     |            |   0%
# py-xgboost-0.90      | 80 KB     | #9         |  20%
# py-xgboost-0.90      | 80 KB     | ###9       |  40%
# py-xgboost-0.90      | 80 KB     | #####9     |  60%
# py-xgboost-0.90      | 80 KB     | #######9   |  80%
# py-xgboost-0.90      | 80 KB     | ########## | 100%
#
# conda-4.9.0          | 3.1 MB    |            |   0%
# conda-4.9.0          | 3.1 MB    |            |   0%
# conda-4.9.0          | 3.1 MB    |            |   1%
# conda-4.9.0          | 3.1 MB    | 1          |   1%
# conda-4.9.0          | 3.1 MB    | 1          |   2%
# conda-4.9.0          | 3.1 MB    | 2          |   3%
# conda-4.9.0          | 3.1 MB    | 3          |   4%
# conda-4.9.0          | 3.1 MB    | 4          |   4%
# conda-4.9.0          | 3.1 MB    | 5          |   5%
# conda-4.9.0          | 3.1 MB    | 5          |   6%
# conda-4.9.0          | 3.1 MB    | 6          |   6%
# conda-4.9.0          | 3.1 MB    | 6          |   7%
# conda-4.9.0          | 3.1 MB    | 7          |   7%
# conda-4.9.0          | 3.1 MB    | 7          |   8%
# conda-4.9.0          | 3.1 MB    | 8          |   8%
# conda-4.9.0          | 3.1 MB    | 8          |   9%
# conda-4.9.0          | 3.1 MB    | 9          |   9%
# conda-4.9.0          | 3.1 MB    | 9          |  10%
# conda-4.9.0          | 3.1 MB    | #          |  10%
# conda-4.9.0          | 3.1 MB    | #1         |  11%
# conda-4.9.0          | 3.1 MB    | #1         |  12%
# conda-4.9.0          | 3.1 MB    | #2         |  12%
# conda-4.9.0          | 3.1 MB    | #2         |  13%
# conda-4.9.0          | 3.1 MB    | #3         |  14%
# conda-4.9.0          | 3.1 MB    | #4         |  14%
# conda-4.9.0          | 3.1 MB    | #4         |  15%
# conda-4.9.0          | 3.1 MB    | #5         |  15%
# conda-4.9.0          | 3.1 MB    | #5         |  16%
# conda-4.9.0          | 3.1 MB    | #6         |  16%
# conda-4.9.0          | 3.1 MB    | #7         |  17%
# conda-4.9.0          | 3.1 MB    | #7         |  18%
# conda-4.9.0          | 3.1 MB    | #8         |  19%
# conda-4.9.0          | 3.1 MB    | #9         |  19%
# conda-4.9.0          | 3.1 MB    | #9         |  20%
# conda-4.9.0          | 3.1 MB    | ##         |  20%
# conda-4.9.0          | 3.1 MB    | ##1        |  21%
# conda-4.9.0          | 3.1 MB    | ##1        |  22%
# conda-4.9.0          | 3.1 MB    | ##2        |  22%
# conda-4.9.0          | 3.1 MB    | ##3        |  23%
# conda-4.9.0          | 3.1 MB    | ##4        |  24%
# conda-4.9.0          | 3.1 MB    | ##4        |  25%
# conda-4.9.0          | 3.1 MB    | ##5        |  25%
# conda-4.9.0          | 3.1 MB    | ##5        |  26%
# conda-4.9.0          | 3.1 MB    | ##6        |  26%
# conda-4.9.0          | 3.1 MB    | ##6        |  27%
# conda-4.9.0          | 3.1 MB    | ##7        |  27%
# conda-4.9.0          | 3.1 MB    | ##8        |  28%
# conda-4.9.0          | 3.1 MB    | ##8        |  29%
# conda-4.9.0          | 3.1 MB    | ##9        |  29%
# conda-4.9.0          | 3.1 MB    | ##9        |  30%
# conda-4.9.0          | 3.1 MB    | ###        |  30%
# conda-4.9.0          | 3.1 MB    | ###        |  31%
# conda-4.9.0          | 3.1 MB    | ###1       |  31%
# conda-4.9.0          | 3.1 MB    | ###1       |  32%
# conda-4.9.0          | 3.1 MB    | ###2       |  32%
# conda-4.9.0          | 3.1 MB    | ###2       |  33%
# conda-4.9.0          | 3.1 MB    | ###3       |  33%
# conda-4.9.0          | 3.1 MB    | ###3       |  34%
# conda-4.9.0          | 3.1 MB    | ###4       |  34%
# conda-4.9.0          | 3.1 MB    | ###4       |  35%
# conda-4.9.0          | 3.1 MB    | ###5       |  35%
# conda-4.9.0          | 3.1 MB    | ###5       |  36%
# conda-4.9.0          | 3.1 MB    | ###6       |  36%
# conda-4.9.0          | 3.1 MB    | ###6       |  37%
# conda-4.9.0          | 3.1 MB    | ###7       |  37%
# conda-4.9.0          | 3.1 MB    | ###7       |  38%
# conda-4.9.0          | 3.1 MB    | ###8       |  38%
# conda-4.9.0          | 3.1 MB    | ###8       |  39%
# conda-4.9.0          | 3.1 MB    | ###9       |  39%
# conda-4.9.0          | 3.1 MB    | ###9       |  40%
# conda-4.9.0          | 3.1 MB    | ####       |  40%
# conda-4.9.0          | 3.1 MB    | ####1      |  42%
# conda-4.9.0          | 3.1 MB    | ####2      |  43%
# conda-4.9.0          | 3.1 MB    | ####3      |  43%
# conda-4.9.0          | 3.1 MB    | ####3      |  44%
# conda-4.9.0          | 3.1 MB    | ####4      |  44%
# conda-4.9.0          | 3.1 MB    | ####4      |  45%
# conda-4.9.0          | 3.1 MB    | ####5      |  45%
# conda-4.9.0          | 3.1 MB    | ####5      |  46%
# conda-4.9.0          | 3.1 MB    | ####6      |  46%
# conda-4.9.0          | 3.1 MB    | ####6      |  47%
# conda-4.9.0          | 3.1 MB    | ####7      |  47%
# conda-4.9.0          | 3.1 MB    | ####7      |  48%
# conda-4.9.0          | 3.1 MB    | ####8      |  48%
# conda-4.9.0          | 3.1 MB    | ####9      |  49%
# conda-4.9.0          | 3.1 MB    | ####9      |  50%
# conda-4.9.0          | 3.1 MB    | #####      |  50%
# conda-4.9.0          | 3.1 MB    | #####      |  51%
# conda-4.9.0          | 3.1 MB    | #####1     |  51%
# conda-4.9.0          | 3.1 MB    | #####1     |  52%
# conda-4.9.0          | 3.1 MB    | #####2     |  52%
# conda-4.9.0          | 3.1 MB    | #####2     |  53%
# conda-4.9.0          | 3.1 MB    | #####3     |  53%
# conda-4.9.0          | 3.1 MB    | #####3     |  54%
# conda-4.9.0          | 3.1 MB    | #####4     |  54%
# conda-4.9.0          | 3.1 MB    | #####4     |  55%
# conda-4.9.0          | 3.1 MB    | #####5     |  55%
# conda-4.9.0          | 3.1 MB    | #####5     |  56%
# conda-4.9.0          | 3.1 MB    | #####6     |  57%
# conda-4.9.0          | 3.1 MB    | #####7     |  57%
# conda-4.9.0          | 3.1 MB    | #####7     |  58%
# conda-4.9.0          | 3.1 MB    | #####8     |  58%
# conda-4.9.0          | 3.1 MB    | #####8     |  59%
# conda-4.9.0          | 3.1 MB    | #####9     |  60%
# conda-4.9.0          | 3.1 MB    | ######     |  60%
# conda-4.9.0          | 3.1 MB    | ######1    |  61%
# conda-4.9.0          | 3.1 MB    | ######1    |  62%
# conda-4.9.0          | 3.1 MB    | ######2    |  62%
# conda-4.9.0          | 3.1 MB    | ######3    |  63%
# conda-4.9.0          | 3.1 MB    | ######4    |  64%
# conda-4.9.0          | 3.1 MB    | ######4    |  65%
# conda-4.9.0          | 3.1 MB    | ######5    |  66%
# conda-4.9.0          | 3.1 MB    | ######6    |  66%
# conda-4.9.0          | 3.1 MB    | ######6    |  67%
# conda-4.9.0          | 3.1 MB    | ######7    |  67%
# conda-4.9.0          | 3.1 MB    | ######7    |  68%
# conda-4.9.0          | 3.1 MB    | ######8    |  69%
# conda-4.9.0          | 3.1 MB    | ######9    |  69%
# conda-4.9.0          | 3.1 MB    | ######9    |  70%
# conda-4.9.0          | 3.1 MB    | #######    |  70%
# conda-4.9.0          | 3.1 MB    | #######    |  71%
# conda-4.9.0          | 3.1 MB    | #######1   |  71%
# conda-4.9.0          | 3.1 MB    | #######1   |  72%
# conda-4.9.0          | 3.1 MB    | #######2   |  72%
# conda-4.9.0          | 3.1 MB    | #######2   |  73%
# conda-4.9.0          | 3.1 MB    | #######3   |  73%
# conda-4.9.0          | 3.1 MB    | #######4   |  74%
# conda-4.9.0          | 3.1 MB    | #######4   |  75%
# conda-4.9.0          | 3.1 MB    | #######5   |  75%
# conda-4.9.0          | 3.1 MB    | #######5   |  76%
# conda-4.9.0          | 3.1 MB    | #######6   |  76%
# conda-4.9.0          | 3.1 MB    | #######7   |  77%
# conda-4.9.0          | 3.1 MB    | #######8   |  78%
# conda-4.9.0          | 3.1 MB    | #######8   |  79%
# conda-4.9.0          | 3.1 MB    | #######9   |  79%
# conda-4.9.0          | 3.1 MB    | #######9   |  80%
# conda-4.9.0          | 3.1 MB    | ########   |  80%
# conda-4.9.0          | 3.1 MB    | ########1  |  81%
# conda-4.9.0          | 3.1 MB    | ########2  |  82%
# conda-4.9.0          | 3.1 MB    | ########3  |  83%
# conda-4.9.0          | 3.1 MB    | ########3  |  84%
# conda-4.9.0          | 3.1 MB    | ########4  |  84%
# conda-4.9.0          | 3.1 MB    | ########4  |  85%
# conda-4.9.0          | 3.1 MB    | ########5  |  85%
# conda-4.9.0          | 3.1 MB    | ########5  |  86%
# conda-4.9.0          | 3.1 MB    | ########6  |  87%
# conda-4.9.0          | 3.1 MB    | ########7  |  87%
# conda-4.9.0          | 3.1 MB    | ########7  |  88%
# conda-4.9.0          | 3.1 MB    | ########8  |  89%
# conda-4.9.0          | 3.1 MB    | ########9  |  89%
# conda-4.9.0          | 3.1 MB    | #########  |  90%
# conda-4.9.0          | 3.1 MB    | #########  |  91%
# conda-4.9.0          | 3.1 MB    | #########1 |  91%
# conda-4.9.0          | 3.1 MB    | #########2 |  92%
# conda-4.9.0          | 3.1 MB    | #########3 |  93%
# conda-4.9.0          | 3.1 MB    | #########4 |  94%
# conda-4.9.0          | 3.1 MB    | #########5 |  95%
# conda-4.9.0          | 3.1 MB    | #########5 |  96%
# conda-4.9.0          | 3.1 MB    | #########6 |  97%
# conda-4.9.0          | 3.1 MB    | #########7 |  98%
# conda-4.9.0          | 3.1 MB    | #########8 |  99%
# conda-4.9.0          | 3.1 MB    | #########9 | 100%
# conda-4.9.0          | 3.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
  conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ENKOYAOUNDE\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0          12 KB
#     backports.functools_lru_cache-1.6.1|     pyhd3eb1b0_0          12 KB
#     conda-4.9.2                |   py37haa95532_0         2.9 MB
#     conda-package-handling-1.7.2|   py37h76e460a_0         724 KB
#     libxgboost-0.90            |                1         1.8 MB
#     ------------------------------------------------------------
#                                            Total:         5.4 MB
#
# The following packages will be UPDATED:
#
#   conda                        anaconda::conda-4.9.0-py37_0 --> pkgs/main::conda-4.9.2-py37haa95532_0
#   conda-package-han~                   1.6.0-py37h62dcd97_0 --> 1.7.2-py37h76e460a_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _py-xgboost-mutex                                anaconda --> pkgs/main
#   libxgboost                                       anaconda --> pkgs/main
#
# The following packages will be DOWNGRADED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.1-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
#
# backports.functools_ | 12 KB     |            |   0%
# backports.functools_ | 12 KB     | ########## | 100%
# backports.functools_ | 12 KB     | ########## | 100%
#
# _py-xgboost-mutex-2. | 12 KB     |            |   0%
# _py-xgboost-mutex-2. | 12 KB     | ########## | 100%
# _py-xgboost-mutex-2. | 12 KB     | ########## | 100%
#
# libxgboost-0.90      | 1.8 MB    |            |   0%
# libxgboost-0.90      | 1.8 MB    |            |   1%
# libxgboost-0.90      | 1.8 MB    | 3          |   3%
# libxgboost-0.90      | 1.8 MB    | 6          |   6%
# libxgboost-0.90      | 1.8 MB    | 8          |   9%
# libxgboost-0.90      | 1.8 MB    | #          |  10%
# libxgboost-0.90      | 1.8 MB    | #2         |  13%
# libxgboost-0.90      | 1.8 MB    | #5         |  15%
# libxgboost-0.90      | 1.8 MB    | #8         |  18%
# libxgboost-0.90      | 1.8 MB    | ##         |  21%
# libxgboost-0.90      | 1.8 MB    | ##4        |  24%
# libxgboost-0.90      | 1.8 MB    | ##6        |  27%
# libxgboost-0.90      | 1.8 MB    | ##9        |  29%
# libxgboost-0.90      | 1.8 MB    | ###1       |  32%
# libxgboost-0.90      | 1.8 MB    | ###6       |  36%
# libxgboost-0.90      | 1.8 MB    | ###8       |  39%
# libxgboost-0.90      | 1.8 MB    | ####2      |  43%
# libxgboost-0.90      | 1.8 MB    | ####6      |  46%
# libxgboost-0.90      | 1.8 MB    | ####9      |  50%
# libxgboost-0.90      | 1.8 MB    | #####3     |  53%
# libxgboost-0.90      | 1.8 MB    | ######     |  60%
# libxgboost-0.90      | 1.8 MB    | ######3    |  64%
# libxgboost-0.90      | 1.8 MB    | ######6    |  67%
# libxgboost-0.90      | 1.8 MB    | #######    |  70%
# libxgboost-0.90      | 1.8 MB    | #######3   |  74%
# libxgboost-0.90      | 1.8 MB    | #######7   |  77%
# libxgboost-0.90      | 1.8 MB    | ########   |  81%
# libxgboost-0.90      | 1.8 MB    | ########4  |  84%
# libxgboost-0.90      | 1.8 MB    | ########7  |  88%
# libxgboost-0.90      | 1.8 MB    | #########1 |  91%
# libxgboost-0.90      | 1.8 MB    | #########4 |  94%
# libxgboost-0.90      | 1.8 MB    | #########7 |  98%
# libxgboost-0.90      | 1.8 MB    | ########## | 100%
#
# conda-package-handli | 724 KB    |            |   0%
# conda-package-handli | 724 KB    | 2          |   2%
# conda-package-handli | 724 KB    | #1         |  11%
# conda-package-handli | 724 KB    | #9         |  20%
# conda-package-handli | 724 KB    | ##4        |  24%
# conda-package-handli | 724 KB    | ##8        |  29%
# conda-package-handli | 724 KB    | ###5       |  35%
# conda-package-handli | 724 KB    | ###9       |  40%
# conda-package-handli | 724 KB    | ####6      |  46%
# conda-package-handli | 724 KB    | #####3     |  53%
# conda-package-handli | 724 KB    | #####9     |  60%
# conda-package-handli | 724 KB    | ######4    |  64%
# conda-package-handli | 724 KB    | #######7   |  77%
# conda-package-handli | 724 KB    | ########3  |  84%
# conda-package-handli | 724 KB    | #########  |  91%
# conda-package-handli | 724 KB    | #########7 |  97%
# conda-package-handli | 724 KB    | ########## | 100%
#
# conda-4.9.2          | 2.9 MB    |            |   0%
# conda-4.9.2          | 2.9 MB    |            |   1%
# conda-4.9.2          | 2.9 MB    | 2          |   2%
# conda-4.9.2          | 2.9 MB    | 3          |   4%
# conda-4.9.2          | 2.9 MB    | 5          |   5%
# conda-4.9.2          | 2.9 MB    | 7          |   7%
# conda-4.9.2          | 2.9 MB    | 8          |   9%
# conda-4.9.2          | 2.9 MB    | #          |  10%
# conda-4.9.2          | 2.9 MB    | #1         |  12%
# conda-4.9.2          | 2.9 MB    | #3         |  14%
# conda-4.9.2          | 2.9 MB    | #4         |  15%
# conda-4.9.2          | 2.9 MB    | #5         |  16%
# conda-4.9.2          | 2.9 MB    | #7         |  17%
# conda-4.9.2          | 2.9 MB    | #8         |  19%
# conda-4.9.2          | 2.9 MB    | ##1        |  22%
# conda-4.9.2          | 2.9 MB    | ##3        |  23%
# conda-4.9.2          | 2.9 MB    | ##5        |  25%
# conda-4.9.2          | 2.9 MB    | ##6        |  27%
# conda-4.9.2          | 2.9 MB    | ##7        |  28%
# conda-4.9.2          | 2.9 MB    | ##9        |  30%
# conda-4.9.2          | 2.9 MB    | ###1       |  32%
# conda-4.9.2          | 2.9 MB    | ###3       |  33%
# conda-4.9.2          | 2.9 MB    | ###5       |  35%
# conda-4.9.2          | 2.9 MB    | ###7       |  38%
# conda-4.9.2          | 2.9 MB    | ###9       |  39%
# conda-4.9.2          | 2.9 MB    | ####       |  41%
# conda-4.9.2          | 2.9 MB    | ####2      |  42%
# conda-4.9.2          | 2.9 MB    | ####4      |  44%
# conda-4.9.2          | 2.9 MB    | ####5      |  46%
# conda-4.9.2          | 2.9 MB    | ####7      |  48%
# conda-4.9.2          | 2.9 MB    | ####9      |  50%
# conda-4.9.2          | 2.9 MB    | #####1     |  51%
# conda-4.9.2          | 2.9 MB    | #####2     |  53%
# conda-4.9.2          | 2.9 MB    | #####4     |  54%
# conda-4.9.2          | 2.9 MB    | #####6     |  56%
# conda-4.9.2          | 2.9 MB    | #####7     |  58%
# conda-4.9.2          | 2.9 MB    | #####9     |  59%
# conda-4.9.2          | 2.9 MB    | ######1    |  61%
# conda-4.9.2          | 2.9 MB    | ######2    |  63%
# conda-4.9.2          | 2.9 MB    | ######6    |  66%
# conda-4.9.2          | 2.9 MB    | ######8    |  69%
# conda-4.9.2          | 2.9 MB    | #######1   |  71%
# conda-4.9.2          | 2.9 MB    | #######4   |  75%
# conda-4.9.2          | 2.9 MB    | #######6   |  76%
# conda-4.9.2          | 2.9 MB    | #######7   |  78%
# conda-4.9.2          | 2.9 MB    | #######8   |  79%
# conda-4.9.2          | 2.9 MB    | ########   |  80%
# conda-4.9.2          | 2.9 MB    | ########1  |  81%
# conda-4.9.2          | 2.9 MB    | ########2  |  82%
# conda-4.9.2          | 2.9 MB    | ########3  |  83%
# conda-4.9.2          | 2.9 MB    | ########4  |  84%
# conda-4.9.2          | 2.9 MB    | ########5  |  86%
# conda-4.9.2          | 2.9 MB    | ########6  |  87%
# conda-4.9.2          | 2.9 MB    | ########7  |  88%
# conda-4.9.2          | 2.9 MB    | ########9  |  90%
# conda-4.9.2          | 2.9 MB    | #########  |  91%
# conda-4.9.2          | 2.9 MB    | #########2 |  92%
# conda-4.9.2          | 2.9 MB    | #########3 |  93%
# conda-4.9.2          | 2.9 MB    | #########4 |  94%
# conda-4.9.2          | 2.9 MB    | #########5 |  95%
# conda-4.9.2          | 2.9 MB    | #########6 |  96%
# conda-4.9.2          | 2.9 MB    | #########8 |  98%
# conda-4.9.2          | 2.9 MB    | #########9 |  99%
# conda-4.9.2          | 2.9 MB    | ########## | 100%
# conda-4.9.2          | 2.9 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
model =XGBClassifier()


numerical_cols = [cname for cname in X_train.columns if 
                X_train[cname].dtype in ['int64', 'float64']]
categorical_cols = [cname for cname in X_train.columns if 
                X_train[cname].dtype in ['object']]

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])
# Bundle preprocessing and modeling code in a pipeline
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('xgb_model', model)
                             ])

# Preprocessing of training data, fit model 
my_pipeline.fit(X_train, y_train)

# Preprocessing of validation data, get predictions
preds = my_pipeline.predict(X_valid)

# %%
from sklearn.metrics import f1_score
print('F1 Score is: ', np.sqrt(f1_score(y_valid, preds)))
# Out:
# F1 Score is:  0.6843316879663908

# %%
from sklearn.model_selection import cross_val_score


scores = cross_val_score(my_pipeline, X, y,
                              cv=5,
                              scoring='f1')

print("f1 score:", scores.mean())
# Out:
# f1 score: 0.07862128740818197

# %%
test_data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/bank_marketing_data/testing_set_label.csv')

# %%
test_data.head()
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   35     management   single   tertiary      no      747      no   no
# 1   36  self-employed  married   tertiary      no      307     yes   no
# 2   39     technician  married  secondary      no      147     yes   no
# 3   41   entrepreneur  married   tertiary      no      221     yes   no
# 4   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome
# 0  cellular   23   feb       141         2    176         3  failure
# 1  cellular   14   may       341         1    330         2    other
# 2  cellular    6   may       151         2     -1         0  unknown
# 3   unknown   14   may        57         2     -1         0  unknown
# 4  cellular   17   apr       313         1    147         2  failure

# %%
X_test=test_data
predictions = my_pipeline.predict(X_test)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
res = pd.DataFrame(predictions) #target is nothing but the final predictions of your model on input features of your new unseen test data
res.index = test_data.index # its important for comparison. Here "test_new" is your new test dataset
res.columns = ['prediction']
res.to_csv("submission.csv")      # the csv file will be saved locally on the same location where this notebook is located.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ENKOYAOUNDE'

# %%
pd.read_csv('submission.csv')
# Out:
#       prediction
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 4504           1
# 4505           0
# 4506           0
# 4507           0
# 4508           0
#
# [4509 rows x 1 columns]

# %%
pip install pandasgui
# Out:
# Collecting pandasgui
#   Downloading pandasgui-0.2.7.tar.gz (6.9 MB)
# Requirement already satisfied: pandas in c:\users\enkoyaounde\anaconda3\lib\site-packages (from pandasgui) (1.1.3)
# Collecting PyQt5
#   Downloading PyQt5-5.15.2-5.15.2-cp35.cp36.cp37.cp38.cp39-none-win_amd64.whl (56.9 MB)
# Collecting PyQt5-sip
#   Downloading PyQt5_sip-12.8.1-cp37-cp37m-win_amd64.whl (62 kB)
# Collecting PyQtWebEngine
#   Downloading PyQtWebEngine-5.15.2-5.15.2-cp35.cp36.cp37.cp38.cp39-none-win_amd64.whl (60.2 MB)
# Collecting plotly
#   Downloading plotly-4.14.1-py2.py3-none-any.whl (13.2 MB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 425, in _error_catcher
#     yield
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 507, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\http\client.py", line 457, in read
#     n = self.readinto(b)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\http\client.py", line 501, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 331, in run
#     resolver.resolve(requirement_set)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\legacy_resolve.py", line 177, in resolve
#     discovered_reqs.extend(self._resolve_one(requirement_set, req))
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\legacy_resolve.py", line 333, in _resolve_one
#     abstract_dist = self._get_abstract_dist_for(req_to_install)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\legacy_resolve.py", line 282, in _get_abstract_dist_for
#     abstract_dist = self.preparer.prepare_linked_requirement(req)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 482, in prepare_linked_requirement
#     hashes=hashes,
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 287, in unpack_url
#     hashes=hashes,
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 159, in unpack_http_url
#     link, downloader, temp_dir.path, hashes
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 303, in _download_http_url
#     for chunk in download.chunks:
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\utils\ui.py", line 160, in iter
#     for x in it:
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 39, in response_chunks
#     decode_content=False,
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 564, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 529, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\ENKOYAOUNDE\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 430, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# Note: you may need to restart the kernel to use updated packages.
